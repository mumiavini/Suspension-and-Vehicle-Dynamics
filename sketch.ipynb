# %%
import polars as pl

# %%
df = pl.read_csv("hardpoints_template.csv")
df
# Out:
# shape: (40, 5)
# ┌────────┬───────────────┬─────────┬────────┬───────┐
# │ corner ┆ point         ┆ x_mm    ┆ y_mm   ┆ z_mm  │
# │ ---    ┆ ---           ┆ ---     ┆ ---    ┆ ---   │
# │ str    ┆ str           ┆ f64     ┆ f64    ┆ f64   │
# ╞════════╪═══════════════╪═════════╪════════╪═══════╡
# │ FL     ┆ UCA_IN_FRONT  ┆ 60.0    ┆ 150.0  ┆ 295.0 │
# │ FL     ┆ UCA_IN_REAR   ┆ -70.0   ┆ 150.0  ┆ 295.0 │
# │ FL     ┆ UCA_OUT       ┆ -5.0    ┆ 590.0  ┆ 280.0 │
# │ FL     ┆ LCA_IN_FRONT  ┆ 90.0    ┆ 130.0  ┆ 162.0 │
# │ FL     ┆ LCA_IN_REAR   ┆ -70.0   ┆ 130.0  ┆ 162.0 │
# │ …      ┆ …             ┆ …       ┆ …      ┆ …     │
# │ RR     ┆ LCA_OUT       ┆ -1535.0 ┆ -600.0 ┆ 152.0 │
# │ RR     ┆ TIE_ROD_IN    ┆ -1600.0 ┆ -180.0 ┆ 200.0 │
# │ RR     ┆ TIE_ROD_OUT   ┆ -1610.0 ┆ -580.0 ┆ 195.0 │
# │ RR     ┆ WHEEL_CENTER  ┆ -1545.0 ┆ -610.0 ┆ 220.0 │
# │ RR     ┆ CONTACT_PATCH ┆ -1545.0 ┆ -610.0 ┆ 0.0   │
# └────────┴───────────────┴─────────┴────────┴───────┘

# %%
df.write_excel("hardpoints_template.xlsx")

# %%
import polars as pl
df_new = pl.read_excel("carro_formula.xlsx")
df_new
# Out:
# shape: (40, 5)
# ┌────────┬───────────────┬─────────┬────────┬────────┐
# │ corner ┆ point         ┆ x_mm    ┆ y_mm   ┆ z_mm   │
# │ ---    ┆ ---           ┆ ---     ┆ ---    ┆ ---    │
# │ str    ┆ str           ┆ f64     ┆ f64    ┆ f64    │
# ╞════════╪═══════════════╪═════════╪════════╪════════╡
# │ FL     ┆ UCA_IN_FRONT  ┆ 141.0   ┆ 294.5  ┆ 354.55 │
# │ FL     ┆ UCA_IN_REAR   ┆ -159.0  ┆ 294.5  ┆ 354.55 │
# │ FL     ┆ UCA_OUT       ┆ 2.9     ┆ 465.41 ┆ 383.76 │
# │ FL     ┆ LCA_IN_FRONT  ┆ 153.0   ┆ 292.0  ┆ 124.0  │
# │ FL     ┆ LCA_IN_REAR   ┆ -147.0  ┆ 292.0  ┆ 124.0  │
# │ …      ┆ …             ┆ …       ┆ …      ┆ …      │
# │ RR     ┆ LCA_OUT       ┆ -1535.0 ┆ -600.0 ┆ 152.0  │
# │ RR     ┆ TIE_ROD_IN    ┆ -1600.0 ┆ -180.0 ┆ 200.0  │
# │ RR     ┆ TIE_ROD_OUT   ┆ -1610.0 ┆ -580.0 ┆ 195.0  │
# │ RR     ┆ WHEEL_CENTER  ┆ -1545.0 ┆ -610.0 ┆ 220.0  │
# │ RR     ┆ CONTACT_PATCH ┆ -1545.0 ┆ -610.0 ┆ 0.0    │
# └────────┴───────────────┴─────────┴────────┴────────┘

# %%
import math

# %%
df_new = df_new.write_csv("carro_formula.csv")

# %%
((12*220*(3.812**2))/2)*0.00002366
# Out:
# 0.4538313107328

# %%
(38527*(1.03**2)*math.cos(math.radians(15)) )/1000
# Out:
# 39.48057056988377

# %%
(266.65/524.47)
# Out:
# 0.508418022003165
